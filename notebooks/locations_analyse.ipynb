# %%
import pandas as pd

pd.options.display.max_columns = 999

# %%
def sample(df, n=3):
    display(df.sample(n))
    display(df.shape)

# %%
df = pd.read_json("data/locations.jsonl", lines=True)
sample(df, 3)
# Out:
#                                  address1                    address2  \
# 426                                  None                        None
# 3186                                 None                        None
# 900   BATIMENT 2 SALLES S021 S022 et S023  2 Rue le Coat Saint-Haouen
#
#                     city    convocationLabel  distance  \
# 426   PLESTIN LES GREVES     Salle des Fêtes         0
# 3186                None  PLEURTUITPL MOBILE         0
# 900              LORIENT        FAC SCIENCES         0
#
#                                             fullAddress  giveBlood  \
# 426                                  PLESTIN LES GREVES          1
# 3186                                                             1
# 900   BATIMENT 2 SALLES S021 S022 et S023 2 Rue le C...          1
#
#       givePlasma  givePlatelet  regionCode groupCode   latitude  longitude  \
# 426            0             0        16.0    F18011  48.663820  -3.611633
# ...

# %%
df.isna().sum(axis=0).sort_values(ascending=False)
# Out:
# ville                   3249
# urlPlatelets            3249
# id                      3249
# urlPlasma               3249
# urlBlood                3249
# phone                   3249
# debutInfos              3249
# finInfos                3249
# tram                    3249
# parking                 3249
# metro                   3249
# bus                     3249
# infos                   3249
# horaires                3248
# address1                2527
# address2                 658
# city                     311
# convocationLabel         116
# name                       5
# regionCode                 1
# distance                   0
# fullAddress                0
# longitude                  0
# latitude                   0
# groupCode                  0
# givePlatelet               0
# giveBlood                  0
# givePlasma                 0
# samplingLocationCode       0
# postCode                   0
# dtype: int64

# %%
na_cols = ["ville", "urlPlatelets", "urlPlasma", "urlBlood", "id", "phone", "debutInfos", "finInfos", "tram", "parking", "metro", "bus", "infos", "horaires"]

df.drop(columns=na_cols, inplace=True)
sample(df, 3)
# Out:
#      address1                               address2         city  \
# 1870     None  Parking CENTRE LECLERC de PONT L'ABBE  PONT L'ABBE
# 282      None                                   None         None
# 494      None                    AVENUE PIERRE DUGOR        AURAY
#
#             convocationLabel  distance  \
# 1870  LIONS CLUB CAMION EFS*         0
# 282         TREVOU TREGUINEC         0
# 494      GYMNASE DE LA FORET         0
#
#                                             fullAddress  giveBlood  \
# 1870  Parking CENTRE LECLERC de PONT L'ABBE 29120 PO...          1
# 282                                                              1
# 494                     AVENUE PIERRE DUGOR 56400 AURAY          1
#
#       givePlasma  givePlatelet  regionCode groupCode   latitude  longitude  \
# 1870           0             0        16.0    F50133  47.864960  -4.227608
# 282            0             0        16.0    F10164   0.000000   0.000000
# ...

# %%
df.postCode.isnull().sum()
# Out:
# np.int64(0)

# %%
df.postCode.str.len().value_counts()
# Out:
# postCode
# 5    2665
# 0     584
# Name: count, dtype: int64

# %%
df_no_postcode = df[df.postCode == ""]
sample(df_no_postcode, 3)
# Out:
#      address1 address2              city  convocationLabel  distance  \
# 1989     None     None  PLONEVEZ DU FAOU  SALLE MUNICIPALE         0
# 76      Brest     None              None  BANQUE DE TISSUS         0
# 1466     None     None        PORT LOUIS     SALLE LOCMALO         0
#
#            fullAddress  giveBlood  givePlasma  givePlatelet  regionCode  \
# 1989  PLONEVEZ DU FAOU          1           0             0        16.0
# 76               Brest          1           0             0        16.0
# 1466        PORT LOUIS          1           0             0        16.0
#
#      groupCode   latitude  longitude               name postCode  \
# 1989    F50199  48.271505  -3.814869   PLONEVEZ DU FAOU
# 76      F00013  48.406435  -4.497736   BANQUE DE TISSUS
# 1466    F38040  16.423578 -61.479707  PORT LOUIS-plasma
#
#      samplingLocationCode
# 1989                  880
# 76                    580
# 1466                    1
# (584, 16)

# %%
df_no_postcode.regionCode.value_counts()
# Out:
# regionCode
# 16.0    584
# Name: count, dtype: int64

# %%
df.regionCode.value_counts()
# Out:
# regionCode
# 16.0    3234
# 19.0       9
# 23.0       5
# Name: count, dtype: int64

# %%
df[(df.regionCode != 16.0) & (df.postCode == "")]
# Out:
# Empty DataFrame
# Columns: [address1, address2, city, convocationLabel, distance, fullAddress, giveBlood, givePlasma, givePlatelet, regionCode, groupCode, latitude, longitude, name, postCode, samplingLocationCode]
# Index: []

# %%
df_brit = df[df.regionCode == 16.0]
sample(df_brit, 3)
# Out:
#      address1                 address2     city  \
# 1843     None             495 LA GREVE  LANVEOC
# 2325     None  AVENUE ALPHONSE LEGAULT     BRUZ
# 2256     None     AVENUE ABBE BARBEDET   ACIGNE
#
#                           convocationLabel  distance  \
# 1843                       ESPACE NAUTIQUE         0
# 2325                   ESPACE VAU GAILLARD         0
# 2256  SALLE GLENMOR (avenue Abbé Barbedet)         0
#
#                              fullAddress  giveBlood  givePlasma  givePlatelet  \
# 1843          495 LA GREVE 29160 LANVEOC          1           0             0
# 2325  AVENUE ALPHONSE LEGAULT 35170 BRUZ          1           0             0
# 2256   AVENUE ABBE BARBEDET 35690 ACIGNE          1           0             0
#
#       regionCode groupCode   latitude  longitude                       name  \
# 1843        16.0    F50124  48.292107  -4.452772  LANVEOC ESPACE NAUTIQUE 1
# 2325        16.0    F70035  48.026524  -1.745072     2 BRUZ-GAILLARD DAM J+
# ...

# %%
df_brit.loc["CP"] = df_brit.postCode.map(lambda x: x[:2] if x else x)
# Out:
# C:\Users\aurel\AppData\Local\Temp\ipykernel_29212\3244517452.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_brit.loc["CP"] = df_brit.postCode.map(lambda x: x[:2] if x else x)

# %%
df_brit[df_brit.CP == "44"]
# Out:
#      address1                address2                 city  \
# 2670     None  RUE DU PARC DES SPORTS  ST NICOLAS DE REDON
# 2671     None  RUE DU PARC DES SPORTS  ST NICOLAS DE REDON
#
#             convocationLabel  distance  \
# 2670  SALLE DU CHATEAU D'EAU       0.0
# 2671  SALLE DU CHATEAU D'EAU       0.0
#
#                                            fullAddress  giveBlood  givePlasma  \
# 2670  RUE DU PARC DES SPORTS 44460 ST NICOLAS DE REDON        1.0         0.0
# 2671  RUE DU PARC DES SPORTS 44460 ST NICOLAS DE REDON        1.0         0.0
#
#       givePlatelet  regionCode groupCode   latitude  longitude  \
# 2670           0.0        16.0    F70187  47.643677  -2.061747
# 2671           0.0        16.0    F70187  47.643677  -2.061747
#
#                          name postCode samplingLocationCode  CP
# 2670  ST NICOLAS DE REDON MAT    44460                   12  44
# 2671   ST NICOLAS DE REDON AM    44460                   13  44

# %%
df_brit.CP.value_counts()
# Out:
# CP
# 35    844
# 56    837
# 29    681
#       584
# 22    279
# 45      3
# 75      3
# 44      2
# 86      1
# Name: count, dtype: int64

# %% [markdown]
# "22", "29", "35", "56"
#
# 45 = ORLEANS
# 75 = PARIS
# 44 = NANTES
# 86 = POITIERS

# %%
df_brit[df_brit.CP == "45"]
# Out:
#                                               address1  \
# 3225  ESPACE MULTI SERVICES - AGGLOMERATION MONTARGOIS
# 3230                                  Salle du Conseil
# 3231                                           Château
#
#                         address2                  city       convocationLabel  \
# 3225       Rue de la Pontonnerie             MONTARGIS  Espace Multi Services
# 3230  17 bis rue Aristide Briant  NOGENT SUR VERNISSON   Nogent sur Vernisson
# 3231              11 rue Pasteur  NOGENT SUR VERNISSON   NOGENT SUR VERNISSON
#
#       distance                                        fullAddress  giveBlood  \
# 3225       0.0  ESPACE MULTI SERVICES - AGGLOMERATION MONTARGO...        1.0
# 3230       0.0  Salle du Conseil 17 bis rue Aristide Briant 45...        1.0
# 3231       0.0  Château 11 rue Pasteur 45270 NOGENT SUR VERNISSON        1.0
#
#       givePlasma  givePlatelet  regionCode groupCode   latitude  longitude  \
# ...

# %%
df_no_brit = df[df.regionCode != 16.0]
df_no_brit
# Out:
#                                     address1  \
# 337                            COAT AN DOC'H
# 3224                                    None
# 3226                                    None
# 3227                                    None
# 3228                                    None
# 3229                                    None
# 3237            SALLES 336 R et 334 R AU RDC
# 3238                                    None
# 3239          SALLES 0304 R et 0334 R AU RDC
# 3240                      SALLE CORVETTO RDC
# 3242                                    None
# 3244  Véhicule de prélèvement sur le parking
# 3245  Véhicule de prélèvement sur le parking
# 3246        CELLULE A CÔTE DE L'ENTREE DARTY
# 3247                      AUDITORIUM LAENNEC
#
#                                         address2                  city  \
# 337                                         None              LANRODEC
# 3224                          16 - 18 rue Carnot             MONTARGIS
# ...

# %%
df.postCode.str.len().value_counts()
# Out:
# postCode
# 5    2665
# 0     584
# Name: count, dtype: int64

# %%
df[df.postCode == ""]
# Out:
#                  address1                           address2   city  \
# 0      Place de la Mairie                               None   None
# 1                  Mairie                               None   None
# 2        Maison pour Tous                               None   None
# 3                    None                               None   None
# 4                    None                               None   None
# ...                   ...                                ...    ...
# 3223                 None                               None   None
# 3232                 None                               None   None
# 3234        Maison du Don  ZA du Sanital - 5 rue Jean Perrin   None
# 3236  PARIS7-MIN DUQUESNE                 14 AVENUE DUQUESNE  PARIS
# 3243                 None                               None   None
#
#                     convocationLabel  distance  \
# 0                          LARGITZEN         0
# 1                    S.P. RETZWILLER         0
# ...
